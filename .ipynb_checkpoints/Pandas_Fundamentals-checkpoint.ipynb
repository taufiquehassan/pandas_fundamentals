# %% [markdown]
# # Introduction to Pandas

# %%
import pandas as pd
import matplotlib as plt

# %%
series = pd.Series(["BMW", "Toyota", "Honda"])
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
colors =  pd.Series(['blue', 'red', 'white'])
colors
# Out:
# 0     blue
# 1      red
# 2    white
# dtype: object

# %%
car_data = pd.DataFrame({'Car Make': series, 'Color': colors})
car_data
# Out:
#   Car Make  Color
# 0      BMW   blue
# 1   Toyota    red
# 2    Honda  white

# %%
car_sales = pd.read_csv('https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/car-sales.csv')

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# # Describing data

# %%
car_sales.dtypes   #attributes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_columns = car_sales.columns

# %%
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales.describe()    #function
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
# Make             10 non-null object
# Colour           10 non-null object
# Odometer (KM)    10 non-null int64
# Doors            10 non-null int64
# Price            10 non-null object
# dtypes: int64(2), object(3)
# memory usage: 480.0+ bytes

# %%
car_sales.mean()
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales['Doors'].sum()
# Out:
# 40

# %%
len(car_sales)
# Out:
# 10

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.tail(2)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %% [markdown]
# ### .loc[] and .iloc[]
# * .ilo[] refers to position
# * .loc[] refers to index

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
car_sales.loc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
car_sales['Make']
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales.Make   # not going to work if the column name has a space in it
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales['Make'].loc[:3]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# Name: Make, dtype: object

# %%
car_sales[car_sales['Make'] == "Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales['Odometer (KM)'] > 10000]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
pd.crosstab(car_sales['Make'], car_sales['Doors'])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
car_sales.groupby(car_sales['Make']).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales['Odometer (KM)'].plot()

# %%
car_sales['Price'].hist()

# %%
car_sales['Price_2'] = car_sales['Price'].str.replace('[\$\,\.]', '').astype(int)/100

# %%
car_sales['Price_2']
# Out:
# 0     4000.0
# 1     5000.0
# 2     7000.0
# 3    22000.0
# 4     3500.0
# 5     4500.0
# 6     7500.0
# 7     7000.0
# 8     6250.0
# 9     9700.0
# Name: Price_2, dtype: float64

# %%
car_sales['Price_2'].hist()

# %% [markdown]
# # Manupulatin Data

# %%
car_sales['Make'] = car_sales['Make'].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Price_2
# 0  toyota  White         150043      4   $4,000.00   4000.0
# 1   honda    Red          87899      4   $5,000.00   5000.0
# 2  toyota   Blue          32549      3   $7,000.00   7000.0
# 3     bmw  Black          11179      5  $22,000.00  22000.0
# 4  nissan  White         213095      4   $3,500.00   3500.0
# 5  toyota  Green          99213      4   $4,500.00   4500.0
# 6   honda   Blue          45698      4   $7,500.00   7500.0
# 7   honda   Blue          54738      4   $7,000.00   7000.0
# 8  toyota  White          60000      4   $6,250.00   6250.0
# 9  nissan  White          31600      4   $9,700.00   9700.0

# %% [markdown]
# ### Filling NaN with something else

# %%
car_sales['Odometer (KM)'] = car_sales['Odometer (KM)'].fillna(car_sales['Odometer (KM)'].mean())

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Price_2
# 0  toyota  White         150043      4   $4,000.00   4000.0
# 1   honda    Red          87899      4   $5,000.00   5000.0
# 2  toyota   Blue          32549      3   $7,000.00   7000.0
# 3     bmw  Black          11179      5  $22,000.00  22000.0
# 4  nissan  White         213095      4   $3,500.00   3500.0
# 5  toyota  Green          99213      4   $4,500.00   4500.0
# 6   honda   Blue          45698      4   $7,500.00   7500.0
# 7   honda   Blue          54738      4   $7,000.00   7000.0
# 8  toyota  White          60000      4   $6,250.00   6250.0
# 9  nissan  White          31600      4   $9,700.00   9700.0

# %%
car_sales =  car_sales.dropna()  # getting rid of NaN

# %% [markdown]
# ### Adding a coulumn

# %% [markdown]
# #### Column from  Series

# %%
car_seats = pd.Series([5,5,5,5,5,5,5])

car_sales['car_seats'] = car_seats
car_sales['car_seats'].fillna(car_sales['car_seats'].mean(), inplace = True)   # filling NaN
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Price_2  car_seats
# 0  toyota  White         150043      4   $4,000.00   4000.0        5.0
# 1   honda    Red          87899      4   $5,000.00   5000.0        5.0
# 2  toyota   Blue          32549      3   $7,000.00   7000.0        5.0
# 3     bmw  Black          11179      5  $22,000.00  22000.0        5.0
# 4  nissan  White         213095      4   $3,500.00   3500.0        5.0
# 5  toyota  Green          99213      4   $4,500.00   4500.0        5.0
# 6   honda   Blue          45698      4   $7,500.00   7500.0        5.0
# 7   honda   Blue          54738      4   $7,000.00   7000.0        5.0
# 8  toyota  White          60000      4   $6,250.00   6250.0        5.0
# 9  nissan  White          31600      4   $9,700.00   9700.0        5.0

# %% [markdown]
# #### Column from python list

# %%
fuel_economy = [2.1, 5.2, 6.1, 6.4, 3.5, 2.1, 5.2, 6.1, 6.4, 3.5]  # Imp note: list requires exact number of items as the index
car_sales["Fuel per 100 km"] = fuel_economy
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Price_2  car_seats  \
# 0  toyota  White         150043      4   $4,000.00   4000.0        5.0
# 1   honda    Red          87899      4   $5,000.00   5000.0        5.0
# 2  toyota   Blue          32549      3   $7,000.00   7000.0        5.0
# 3     bmw  Black          11179      5  $22,000.00  22000.0        5.0
# 4  nissan  White         213095      4   $3,500.00   3500.0        5.0
# 5  toyota  Green          99213      4   $4,500.00   4500.0        5.0
# 6   honda   Blue          45698      4   $7,500.00   7500.0        5.0
# 7   honda   Blue          54738      4   $7,000.00   7000.0        5.0
# 8  toyota  White          60000      4   $6,250.00   6250.0        5.0
# 9  nissan  White          31600      4   $9,700.00   9700.0        5.0
#
#    Fuel per 100 km
# 0              2.1
# 1              5.2
# 2              6.1
# 3              6.4
# 4              3.5
# 5              2.1
# 6              5.2
# 7              6.1
# 8              6.4
# 9              3.5

# %% [markdown]
# #### Column from a number

# %%
car_sales["Number of Wheels"] = 4
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Price_2  car_seats  \
# 0  toyota  White         150043      4   $4,000.00   4000.0        5.0
# 1   honda    Red          87899      4   $5,000.00   5000.0        5.0
# 2  toyota   Blue          32549      3   $7,000.00   7000.0        5.0
# 3     bmw  Black          11179      5  $22,000.00  22000.0        5.0
# 4  nissan  White         213095      4   $3,500.00   3500.0        5.0
# 5  toyota  Green          99213      4   $4,500.00   4500.0        5.0
# 6   honda   Blue          45698      4   $7,500.00   7500.0        5.0
# 7   honda   Blue          54738      4   $7,000.00   7000.0        5.0
# 8  toyota  White          60000      4   $6,250.00   6250.0        5.0
# 9  nissan  White          31600      4   $9,700.00   9700.0        5.0
#
#    Fuel per 100 km  Number of Wheels
# 0              2.1                 4
# 1              5.2                 4
# 2              6.1                 4
# 3              6.4                 4
# 4              3.5                 4
# 5              2.1                 4
# 6              5.2                 4
# 7              6.1                 4
# 8              6.4                 4
# 9              3.5                 4

# %% [markdown]
# #### Adding a bool column

# %%
car_sales["Passed Road Safety"] = True
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Price_2  car_seats  \
# 0  toyota  White         150043      4   $4,000.00   4000.0        5.0
# 1   honda    Red          87899      4   $5,000.00   5000.0        5.0
# 2  toyota   Blue          32549      3   $7,000.00   7000.0        5.0
# 3     bmw  Black          11179      5  $22,000.00  22000.0        5.0
# 4  nissan  White         213095      4   $3,500.00   3500.0        5.0
# 5  toyota  Green          99213      4   $4,500.00   4500.0        5.0
# 6   honda   Blue          45698      4   $7,500.00   7500.0        5.0
# 7   honda   Blue          54738      4   $7,000.00   7000.0        5.0
# 8  toyota  White          60000      4   $6,250.00   6250.0        5.0
# 9  nissan  White          31600      4   $9,700.00   9700.0        5.0
#
#    Fuel per 100 km  Number of Wheels  Passed Road Safety
# 0              2.1                 4                True
# 1              5.2                 4                True
# 2              6.1                 4                True
# 3              6.4                 4                True
# 4              3.5                 4                True
# 5              2.1                 4                True
# 6              5.2                 4                True
# 7              6.1                 4                True
# 8              6.4                 4                True
# 9              3.5                 4                True

# %% [markdown]
# ### Performing operations on columns

# %%
car_sales['Total Fuel Used'] = car_sales['Odometer (KM)']/car_sales["Fuel per 100 km"]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Price_2  car_seats  \
# 0  toyota  White         150043      4   $4,000.00   4000.0        5.0
# 1   honda    Red          87899      4   $5,000.00   5000.0        5.0
# 2  toyota   Blue          32549      3   $7,000.00   7000.0        5.0
# 3     bmw  Black          11179      5  $22,000.00  22000.0        5.0
# 4  nissan  White         213095      4   $3,500.00   3500.0        5.0
# 5  toyota  Green          99213      4   $4,500.00   4500.0        5.0
# 6   honda   Blue          45698      4   $7,500.00   7500.0        5.0
# 7   honda   Blue          54738      4   $7,000.00   7000.0        5.0
# 8  toyota  White          60000      4   $6,250.00   6250.0        5.0
# 9  nissan  White          31600      4   $9,700.00   9700.0        5.0
#
#    Fuel per 100 km  Number of Wheels  Passed Road Safety  Total Fuel Used
# 0              2.1                 4                True     71449.047619
# 1              5.2                 4                True     16903.653846
# 2              6.1                 4                True      5335.901639
# 3              6.4                 4                True      1746.718750
# 4              3.5                 4                True     60884.285714
# 5              2.1                 4                True     47244.285714
# 6              5.2                 4                True      8788.076923
# 7              6.1                 4                True      8973.442623
# 8              6.4                 4                True      9375.000000
# 9              3.5                 4                True      9028.571429

# %% [markdown]
# #### Deleting a column

# %%
car_sales = car_sales.drop('Price_2', axis = 1)   # axis=1 for any column
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  car_seats  \
# 0  toyota  White         150043      4   $4,000.00        5.0
# 1   honda    Red          87899      4   $5,000.00        5.0
# 2  toyota   Blue          32549      3   $7,000.00        5.0
# 3     bmw  Black          11179      5  $22,000.00        5.0
# 4  nissan  White         213095      4   $3,500.00        5.0
# 5  toyota  Green          99213      4   $4,500.00        5.0
# 6   honda   Blue          45698      4   $7,500.00        5.0
# 7   honda   Blue          54738      4   $7,000.00        5.0
# 8  toyota  White          60000      4   $6,250.00        5.0
# 9  nissan  White          31600      4   $9,700.00        5.0
#
#    Fuel per 100 km  Number of Wheels  Passed Road Safety  Total Fuel Used
# 0              2.1                 4                True     71449.047619
# 1              5.2                 4                True     16903.653846
# 2              6.1                 4                True      5335.901639
# 3              6.4                 4                True      1746.718750
# 4              3.5                 4                True     60884.285714
# 5              2.1                 4                True     47244.285714
# 6              5.2                 4                True      8788.076923
# 7              6.1                 4                True      8973.442623
# 8              6.4                 4                True      9375.000000
# 9              3.5                 4                True      9028.571429

# %% [markdown]
# ### Manupulating rows

# %% [markdown]
# #### Shuffle All Rows

# %%
car_sales_sample = car_sales.sample(frac=1)  
car_sales_sample
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  car_seats  \
# 9  nissan  White          31600      4   $9,700.00        5.0
# 1   honda    Red          87899      4   $5,000.00        5.0
# 8  toyota  White          60000      4   $6,250.00        5.0
# 5  toyota  Green          99213      4   $4,500.00        5.0
# 4  nissan  White         213095      4   $3,500.00        5.0
# 0  toyota  White         150043      4   $4,000.00        5.0
# 2  toyota   Blue          32549      3   $7,000.00        5.0
# 6   honda   Blue          45698      4   $7,500.00        5.0
# 7   honda   Blue          54738      4   $7,000.00        5.0
# 3     bmw  Black          11179      5  $22,000.00        5.0
#
#    Fuel per 100 km  Number of Wheels  Passed Road Safety  Total Fuel Used
# 9              3.5                 4                True      9028.571429
# 1              5.2                 4                True     16903.653846
# 8              6.4                 4                True      9375.000000
# 5              2.1                 4                True     47244.285714
# 4              3.5                 4                True     60884.285714
# 0              2.1                 4                True     71449.047619
# 2              6.1                 4                True      5335.901639
# 6              5.2                 4                True      8788.076923
# 7              6.1                 4                True      8973.442623
# 3              6.4                 4                True      1746.718750

# %% [markdown]
# #### Sample of the dataset

# %%
car_sales_sample = car_sales.sample(frac=0.5)   # randomly selected 50% of the data
car_sales_sample
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  car_seats  \
# 6   honda   Blue          45698      4   $7,500.00        5.0
# 1   honda    Red          87899      4   $5,000.00        5.0
# 3     bmw  Black          11179      5  $22,000.00        5.0
# 2  toyota   Blue          32549      3   $7,000.00        5.0
# 5  toyota  Green          99213      4   $4,500.00        5.0
#
#    Fuel per 100 km  Number of Wheels  Passed Road Safety  Total Fuel Used
# 6              5.2                 4                True      8788.076923
# 1              5.2                 4                True     16903.653846
# 3              6.4                 4                True      1746.718750
# 2              6.1                 4                True      5335.901639
# 5              2.1                 4                True     47244.285714
